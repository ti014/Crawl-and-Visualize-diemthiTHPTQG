# %%
import pandas as pd

# %%
import os

filepath = 'crawl_data_thptqg_2022.csv'

if os.path.exists(filepath):
    with open(filepath, 'r') as file:
        # Tiếp tục xử lý file tại đây
        pass
else:
    print("File not found:", filepath)

# %%
df = pd.read_csv(filepath)
df.head()
# Out:
#        SBD                           Sở GD  Toán   Văn   Sử  Địa    Lí  Hoá  \
# 0  2000001  Sở GD&ĐT Thành Phố Hồ Chí Minh   7.4  7.25  NaN  NaN  7.75  NaN
# 1  2000002  Sở GD&ĐT Thành Phố Hồ Chí Minh   8.4  7.50  NaN  NaN  7.50  NaN
# 2  2000003  Sở GD&ĐT Thành Phố Hồ Chí Minh   8.4  6.50  NaN  NaN  6.50  NaN
# 3  2000004  Sở GD&ĐT Thành Phố Hồ Chí Minh   8.8  5.50  NaN  NaN  8.25  NaN
# 4  2000005  Sở GD&ĐT Thành Phố Hồ Chí Minh   7.2  7.25  6.0  4.5   NaN  NaN
#
#    Sinh  Ngoại ngữ  GDCD  Năm thi
# 0   5.5        9.8   NaN     2022
# 1   4.5        9.4   NaN     2022
# 2   4.5        4.2   NaN     2022
# 3   6.0        8.8   NaN     2022
# 4   NaN        9.4   7.5     2022
